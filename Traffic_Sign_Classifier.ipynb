# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier

# %% [markdown]
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

training_file = "./traffic-signs-data/train.p"
validation_file="./traffic-signs-data/valid.p"
testing_file = "./traffic-signs-data/test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
import numpy as np

n_train = X_train.shape[0]
n_valid = X_valid.shape[0]
n_test = X_test.shape[0]
image_shape = X_train.shape[1:]

n_classes = np.unique(y_train).shape[0]

print("Number of training examples =", n_train)
print("Number of validation examples =", n_valid)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of validation examples = 4410
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import random 

# Visualizations will be shown in the notebook.
get_ipython().magic('matplotlib inline')

def draw_images_examples(image_array, grid_x, grid_y, title):
    fig = plt.figure(figsize=(grid_x,grid_y))
    fig.suptitle(title, fontsize=20)
 
    for i in range(1,grid_y*grid_x+1):
        index = random.randint(0, len(image_array))
        image = image_array[index].squeeze()
       
        plt.subplot(grid_y,grid_x,i)
        plt.imshow(image)
        
draw_images_examples(X_train, 16, 4, 'Examples of images from training set')
    

fig = plt.figure(figsize=(12,4))
n, bins, patches = plt.hist(y_train, n_classes)
plt.xlabel('Labels')
plt.ylabel('No. of samples')
plt.title('Histogram of training samples')

X_train_one_label = X_train[np.where(y_train==0)]
draw_images_examples(X_train_one_label, 16, 4, 'Examples of images of the same type - Speed limit (20km/h)')

# %% [markdown]
# ## Step 2: Design and Test a Model Architecture

# %% [markdown]
# # Preprocess the data here. Preprocessing steps could include normalization, converting to grayscale, etc.

# %% [markdown]
# ### Equalize histograms of training samples - by generation of additional, transformed images

# %%
from tqdm import tqdm
from scipy import ndimage
import cv2 

def augment_brightness_camera_images(image):
    image1 = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)
    random_bright = .25+np.random.uniform()
    image1[:,:,2] = image1[:,:,2]*random_bright
    image1 = cv2.cvtColor(image1,cv2.COLOR_HSV2RGB)
    return image1

def transform_image(img):    
    ang_range = 25
    ang_rot = np.random.uniform(ang_range)-ang_range/2
    rows,cols,ch = img.shape    
    Rot_M = cv2.getRotationMatrix2D((cols/2,rows/2),ang_rot,1)
        
    img = cv2.warpAffine(img,Rot_M,(cols,rows))    
    img = augment_brightness_camera_images(img)
    
    return img

def get_random_image_of_given_label(images_set, labels_set, label):
    image_indexes = np.where(labels_set == label)
    rand_index = random.randint(0, np.bincount(labels_set)[label] - 1)
    return images_set[image_indexes][rand_index]

def equalize_samples_set(X_set, y_set):
    labels_count_arr = np.bincount(y_set)
    labels_bins = np.arange(len(labels_count_arr))
    
    ind = 0    
   
    for label in tqdm(labels_bins):        
        labels_no_to_add =  int(np.mean(labels_count_arr)) * 4 - labels_count_arr[label]
        
        ind = ind + 1
        X_temp = []
        y_temp = []
        
        for num in range(labels_no_to_add):      
            rand_image = get_random_image_of_given_label(X_set, y_set, label)
            X_temp.append(transform_image(rand_image))
            y_temp.append(label)            
   
        X_set = np.append(X_set, np.array(X_temp), axis=0)
        y_set = np.append(y_set, np.array(y_temp), axis=0)
        
    return X_set, y_set


X_train, y_train = equalize_samples_set(X_train, y_train)

n, bins, patches = plt.hist(y_train, n_classes)
plt.xlabel('Labels')
plt.ylabel('No. of samples')
plt.title('Equalized histogram of train samples')
plt.show()

print("Train set increased from {} to {}".format(n_train,X_train.shape[0]))

fig=plt.figure()
fig.suptitle('Test image to transform', fontsize=16)
plt.imshow(X_train[1000])

grid_len = 4
fig=plt.figure(figsize=(grid_len,grid_len))
fig.suptitle('Test images after transformation', fontsize=16)
 
for i in range(1,grid_len*grid_len+1):
    image = transform_image(X_train[1000])
    plt.subplot(grid_len,grid_len,i)
    plt.imshow(image)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 43/43 [02:23<00:00,  3.69s/it]
# Train set increased from 34799 to 139148

# %% [markdown]
# ### Image normalization and grayscale conversion

# %%
import cv2
import tensorflow as tf
from tensorflow.contrib.layers import flatten

def grayscale(img):    
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)[:,:,None]

def normalize(value):
    return value / 255 * 2 - 1

def preprocess_image(image):
    img = grayscale(image)
    img = normalize(img)
    return img

from tqdm import tqdm
def preprocess_batch(images):
    imgs = np.zeros(shape=images.shape)
    processed_image_depth = preprocess_image(images[0]).shape[2]
    imgs = imgs[:,:,:,0:processed_image_depth]
    for i in tqdm(range(images.shape[0])):
        imgs[i] = preprocess_image(images[i])        
    return imgs

X_train_processed = preprocess_batch(X_train)
X_valid_processed = preprocess_batch(X_valid)
X_test_processed = preprocess_batch(X_test)

no_test_image = 10000

sample_image = X_train[no_test_image]
sample_image_processed = grayscale(X_train[no_test_image])
fig=plt.figure(figsize=(16,3))
sub=plt.subplot(131)
sub.set_title("Original image")
plt.imshow(sample_image)
sub=plt.subplot(132)
sub.set_title("Preprocessed image")
plt.imshow(sample_image_processed.squeeze(), cmap='gray')

print("Sample image dimension BEFORE processing: {}".format(sample_image.shape))
print("Sample image dimension AFTER processing: {}".format(sample_image_processed.shape))

image_depth = X_train_processed.shape[3]

sample_image = X_train[no_test_image]
dim1 = sample_image.shape[0]
dim2 = sample_image.shape[1]
dim3 = sample_image.shape[2]
sample_image_reshaped = np.reshape(sample_image, dim1*dim2*dim3)
plt.figure(figsize=(16,3))
sub=plt.subplot(131)
sub.set_title("Original image histogram")
n, bins, patches = plt.hist(sample_image_reshaped, 255)

sample_image_processed = X_train_processed[no_test_image]
dim1 = sample_image_processed.shape[0]
dim2 = sample_image_processed.shape[1]
dim3 = sample_image_processed.shape[2]
sample_image_processed_reshaped = np.reshape(sample_image_processed, dim1*dim2*dim3)
sub=plt.subplot(132)
sub.set_title("Preprocessed image histogram")
n, bins, patches = plt.hist(sample_image_processed_reshaped,255)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 139148/139148 [00:03<00:00, 36160.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 4410/4410 [00:00<00:00, 26734.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 12630/12630 [00:00<00:00, 37048.71it/s]
# Sample image dimension BEFORE processing: (32, 32, 3)
# Sample image dimension AFTER processing: (32, 32, 1)

# %% [markdown]
# ### Model Architecture

# %%
import tensorflow as tf
from tensorflow.contrib.layers import flatten

EPOCHS = 200
BATCH_SIZE = 128

def LeNet(x):
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    
    # SOLUTION: Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(5, 5, image_depth, 6), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(6))
    conv1   = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='VALID') + conv1_b

    # SOLUTION: Activation.
    conv1 = tf.nn.relu(conv1)
    
    # SOLUTION: Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1 = tf.nn.avg_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Layer 2: Convolutional. Output = 10x10x16.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(16))
    conv2   = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding='VALID') + conv2_b
    
    # SOLUTION: Activation.
    conv2 = tf.nn.relu(conv2)
        
    # SOLUTION: Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2 = tf.nn.avg_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Flatten. Input = 5x5x16. Output = 400.
    fc0   = flatten(conv2)
    
    # SOLUTION: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(400, 120), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(120))
    fc1   = tf.matmul(fc0, fc1_W) + fc1_b
    
    # SOLUTION: Activation.
    fc1    = tf.nn.relu(fc1)
    
    # SOLUTION: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_W  = tf.Variable(tf.truncated_normal(shape=(120, 84), mean = mu, stddev = sigma))
    fc2_b  = tf.Variable(tf.zeros(84))
    fc2    = tf.matmul(fc1, fc2_W) + fc2_b
    
    # SOLUTION: Activation.
    fc2    = tf.nn.relu(fc2)
    
    # SOLUTION: Layer 5: Fully Connected. Input = 84. Output = 43.
    fc3_W  = tf.Variable(tf.truncated_normal(shape=(84, n_classes), mean = mu, stddev = sigma))
    fc3_b  = tf.Variable(tf.zeros(n_classes))
    logits = tf.matmul(fc2, fc3_W) + fc3_b
    
    return logits


x = tf.placeholder(tf.float32, (None, 32, 32, image_depth))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, n_classes)

rate = 0.003

logits = LeNet(x)

varss = tf.trainable_variables() 
lossL2 = tf.add_n([ tf.nn.l2_loss(v) for v in varss
                    if '_b' not in v.name ]) * 0.0001

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits, one_hot_y)
loss_operation = tf.reduce_mean(cross_entropy) + lossL2
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)



correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
from sklearn.utils import shuffle

cost_arr = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train_processed)
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train_processed, y_train = shuffle(X_train_processed, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train_processed[offset:end], y_train[offset:end]
            to, cost = sess.run([training_operation, loss_operation], feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid_processed, y_valid)
        print("EPOCH; {}; Valid.Acc.; {:.3f}; Loss; {:.5f}".format(i+1, validation_accuracy, cost))
        cost_arr.append(cost)
      
        
    saver.save(sess, './lenet')
    print("Model saved")


with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('.'))

    test_accuracy = evaluate(X_test_processed, y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy))
    
plt.plot(cost_arr)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
# Out:
# Training...
#
# EPOCH; 1; Valid.Acc.; 0.877; Loss; 0.56234
# EPOCH; 2; Valid.Acc.; 0.928; Loss; 0.41210
# EPOCH; 3; Valid.Acc.; 0.909; Loss; 0.12076
# EPOCH; 4; Valid.Acc.; 0.927; Loss; 0.10470
# EPOCH; 5; Valid.Acc.; 0.924; Loss; 0.46599
# EPOCH; 6; Valid.Acc.; 0.936; Loss; 0.08682
# EPOCH; 7; Valid.Acc.; 0.925; Loss; 0.20130
# EPOCH; 8; Valid.Acc.; 0.941; Loss; 0.32556
# EPOCH; 9; Valid.Acc.; 0.940; Loss; 0.16499
# EPOCH; 10; Valid.Acc.; 0.935; Loss; 0.09020
# EPOCH; 11; Valid.Acc.; 0.936; Loss; 0.10343
# EPOCH; 12; Valid.Acc.; 0.929; Loss; 0.10352
# EPOCH; 13; Valid.Acc.; 0.954; Loss; 0.13675
# EPOCH; 14; Valid.Acc.; 0.945; Loss; 0.10995
# EPOCH; 15; Valid.Acc.; 0.916; Loss; 0.48491
# EPOCH; 16; Valid.Acc.; 0.932; Loss; 0.11821
# EPOCH; 17; Valid.Acc.; 0.951; Loss; 0.11897
# EPOCH; 18; Valid.Acc.; 0.938; Loss; 0.08685
# EPOCH; 19; Valid.Acc.; 0.945; Loss; 0.08105
# EPOCH; 20; Valid.Acc.; 0.951; Loss; 0.08949
# EPOCH; 21; Valid.Acc.; 0.952; Loss; 0.08533
# EPOCH; 22; Valid.Acc.; 0.959; Loss; 0.08957
# EPOCH; 23; Valid.Acc.; 0.956; Loss; 0.11091
# EPOCH; 24; Valid.Acc.; 0.940; Loss; 0.09252
# EPOCH; 25; Valid.Acc.; 0.953; Loss; 0.07937
# EPOCH; 26; Valid.Acc.; 0.955; Loss; 0.08038
# EPOCH; 27; Valid.Acc.; 0.961; Loss; 0.07742
# EPOCH; 28; Valid.Acc.; 0.956; Loss; 0.07727
# EPOCH; 29; Valid.Acc.; 0.959; Loss; 0.07510
# EPOCH; 30; Valid.Acc.; 0.939; Loss; 0.09298
# EPOCH; 31; Valid.Acc.; 0.962; Loss; 0.10243
# EPOCH; 32; Valid.Acc.; 0.959; Loss; 0.07916
# EPOCH; 33; Valid.Acc.; 0.952; Loss; 0.07718
# EPOCH; 34; Valid.Acc.; 0.951; Loss; 0.12323
# EPOCH; 35; Valid.Acc.; 0.960; Loss; 0.10598
# EPOCH; 36; Valid.Acc.; 0.946; Loss; 0.07832
# EPOCH; 37; Valid.Acc.; 0.951; Loss; 0.07462
# EPOCH; 38; Valid.Acc.; 0.950; Loss; 0.07578
# EPOCH; 39; Valid.Acc.; 0.946; Loss; 0.07915
# EPOCH; 40; Valid.Acc.; 0.958; Loss; 0.10347
# EPOCH; 41; Valid.Acc.; 0.961; Loss; 0.07468
# EPOCH; 42; Valid.Acc.; 0.945; Loss; 0.07587
# EPOCH; 43; Valid.Acc.; 0.962; Loss; 0.07688
# EPOCH; 44; Valid.Acc.; 0.955; Loss; 0.12788
# EPOCH; 45; Valid.Acc.; 0.947; Loss; 0.07377
# EPOCH; 46; Valid.Acc.; 0.955; Loss; 0.07240
# EPOCH; 47; Valid.Acc.; 0.950; Loss; 0.07270
# EPOCH; 48; Valid.Acc.; 0.945; Loss; 0.07799
# EPOCH; 49; Valid.Acc.; 0.955; Loss; 0.08697
# EPOCH; 50; Valid.Acc.; 0.949; Loss; 0.08783
# EPOCH; 51; Valid.Acc.; 0.956; Loss; 0.07415
# EPOCH; 52; Valid.Acc.; 0.951; Loss; 0.07222
# EPOCH; 53; Valid.Acc.; 0.962; Loss; 0.07377
# EPOCH; 54; Valid.Acc.; 0.963; Loss; 0.07638
# EPOCH; 55; Valid.Acc.; 0.949; Loss; 0.44474
# EPOCH; 56; Valid.Acc.; 0.961; Loss; 0.07374
# EPOCH; 57; Valid.Acc.; 0.955; Loss; 0.08289
# EPOCH; 58; Valid.Acc.; 0.960; Loss; 0.07847
# EPOCH; 59; Valid.Acc.; 0.955; Loss; 0.07299
# EPOCH; 60; Valid.Acc.; 0.956; Loss; 0.07649
# EPOCH; 61; Valid.Acc.; 0.951; Loss; 0.07135
# EPOCH; 62; Valid.Acc.; 0.968; Loss; 0.07747
# EPOCH; 63; Valid.Acc.; 0.960; Loss; 0.07191
# EPOCH; 64; Valid.Acc.; 0.959; Loss; 0.07122
# EPOCH; 65; Valid.Acc.; 0.954; Loss; 0.07768
# EPOCH; 66; Valid.Acc.; 0.957; Loss; 0.08210
# EPOCH; 67; Valid.Acc.; 0.952; Loss; 0.07165
# EPOCH; 68; Valid.Acc.; 0.965; Loss; 0.07601
# EPOCH; 69; Valid.Acc.; 0.962; Loss; 0.07031
# EPOCH; 70; Valid.Acc.; 0.954; Loss; 0.07637
# EPOCH; 71; Valid.Acc.; 0.956; Loss; 0.07163
# EPOCH; 72; Valid.Acc.; 0.951; Loss; 0.14352
# EPOCH; 73; Valid.Acc.; 0.963; Loss; 0.06906
# EPOCH; 74; Valid.Acc.; 0.956; Loss; 0.11785
# EPOCH; 75; Valid.Acc.; 0.966; Loss; 0.07047
# EPOCH; 76; Valid.Acc.; 0.954; Loss; 0.07314
# EPOCH; 77; Valid.Acc.; 0.952; Loss; 0.11030
# EPOCH; 78; Valid.Acc.; 0.956; Loss; 0.06843
# EPOCH; 79; Valid.Acc.; 0.960; Loss; 0.06914
# EPOCH; 80; Valid.Acc.; 0.960; Loss; 0.06911
# EPOCH; 81; Valid.Acc.; 0.957; Loss; 0.06858
# EPOCH; 82; Valid.Acc.; 0.954; Loss; 0.07797
# EPOCH; 83; Valid.Acc.; 0.965; Loss; 0.06872
# EPOCH; 84; Valid.Acc.; 0.953; Loss; 0.06862
# EPOCH; 85; Valid.Acc.; 0.965; Loss; 0.14560
# EPOCH; 86; Valid.Acc.; 0.957; Loss; 0.06867
# EPOCH; 87; Valid.Acc.; 0.961; Loss; 0.06781
# EPOCH; 88; Valid.Acc.; 0.951; Loss; 0.06836
# EPOCH; 89; Valid.Acc.; 0.966; Loss; 0.07010
# EPOCH; 90; Valid.Acc.; 0.959; Loss; 0.06967
# EPOCH; 91; Valid.Acc.; 0.959; Loss; 0.23803
# EPOCH; 92; Valid.Acc.; 0.964; Loss; 0.07048
# EPOCH; 93; Valid.Acc.; 0.964; Loss; 0.07953
# EPOCH; 94; Valid.Acc.; 0.960; Loss; 0.06829
# EPOCH; 95; Valid.Acc.; 0.957; Loss; 0.06760
# EPOCH; 96; Valid.Acc.; 0.963; Loss; 0.06801
# EPOCH; 97; Valid.Acc.; 0.957; Loss; 0.06829
# EPOCH; 98; Valid.Acc.; 0.957; Loss; 0.06676
# EPOCH; 99; Valid.Acc.; 0.971; Loss; 0.08273
# EPOCH; 100; Valid.Acc.; 0.956; Loss; 0.06715
# EPOCH; 101; Valid.Acc.; 0.961; Loss; 0.07838
# EPOCH; 102; Valid.Acc.; 0.965; Loss; 0.07530
# EPOCH; 103; Valid.Acc.; 0.959; Loss; 0.06780
# EPOCH; 104; Valid.Acc.; 0.963; Loss; 0.07100
# EPOCH; 105; Valid.Acc.; 0.956; Loss; 0.06725
# EPOCH; 106; Valid.Acc.; 0.962; Loss; 0.06764
# EPOCH; 107; Valid.Acc.; 0.965; Loss; 0.06689
# EPOCH; 108; Valid.Acc.; 0.958; Loss; 0.06718
# EPOCH; 109; Valid.Acc.; 0.953; Loss; 0.09750
# EPOCH; 110; Valid.Acc.; 0.966; Loss; 0.06879
# EPOCH; 111; Valid.Acc.; 0.950; Loss; 0.07135
# EPOCH; 112; Valid.Acc.; 0.959; Loss; 0.06689
# EPOCH; 113; Valid.Acc.; 0.964; Loss; 0.12501
# EPOCH; 114; Valid.Acc.; 0.960; Loss; 0.06923
# EPOCH; 115; Valid.Acc.; 0.953; Loss; 0.06938
# EPOCH; 116; Valid.Acc.; 0.960; Loss; 0.08725
# EPOCH; 117; Valid.Acc.; 0.963; Loss; 0.06838
# EPOCH; 118; Valid.Acc.; 0.955; Loss; 0.07197
# EPOCH; 119; Valid.Acc.; 0.962; Loss; 0.06602
# EPOCH; 120; Valid.Acc.; 0.963; Loss; 0.06698
# EPOCH; 121; Valid.Acc.; 0.960; Loss; 0.08316
# EPOCH; 122; Valid.Acc.; 0.965; Loss; 0.10578
# EPOCH; 123; Valid.Acc.; 0.958; Loss; 0.15881
# EPOCH; 124; Valid.Acc.; 0.963; Loss; 0.06749
# EPOCH; 125; Valid.Acc.; 0.968; Loss; 0.06794
# EPOCH; 126; Valid.Acc.; 0.955; Loss; 0.06709
# EPOCH; 127; Valid.Acc.; 0.960; Loss; 0.07457
# EPOCH; 128; Valid.Acc.; 0.957; Loss; 0.07235
# EPOCH; 129; Valid.Acc.; 0.964; Loss; 0.10292
# EPOCH; 130; Valid.Acc.; 0.959; Loss; 0.06760
# EPOCH; 131; Valid.Acc.; 0.963; Loss; 0.06646
# EPOCH; 132; Valid.Acc.; 0.967; Loss; 0.06574
# EPOCH; 133; Valid.Acc.; 0.963; Loss; 0.06805
# EPOCH; 134; Valid.Acc.; 0.965; Loss; 0.06847
# EPOCH; 135; Valid.Acc.; 0.966; Loss; 0.06813
# EPOCH; 136; Valid.Acc.; 0.965; Loss; 0.06655
# EPOCH; 137; Valid.Acc.; 0.963; Loss; 0.10273
# EPOCH; 138; Valid.Acc.; 0.964; Loss; 0.06804
# EPOCH; 139; Valid.Acc.; 0.957; Loss; 0.09802
# EPOCH; 140; Valid.Acc.; 0.960; Loss; 0.06664
# EPOCH; 141; Valid.Acc.; 0.961; Loss; 0.06523
# EPOCH; 142; Valid.Acc.; 0.959; Loss; 0.06881
# EPOCH; 143; Valid.Acc.; 0.952; Loss; 0.09327
# EPOCH; 144; Valid.Acc.; 0.962; Loss; 0.06716
# EPOCH; 145; Valid.Acc.; 0.967; Loss; 0.06671
# EPOCH; 146; Valid.Acc.; 0.958; Loss; 0.06550
# EPOCH; 147; Valid.Acc.; 0.959; Loss; 0.06752
# EPOCH; 148; Valid.Acc.; 0.964; Loss; 0.06502
# EPOCH; 149; Valid.Acc.; 0.954; Loss; 0.07008
# EPOCH; 150; Valid.Acc.; 0.959; Loss; 0.07588
# EPOCH; 151; Valid.Acc.; 0.949; Loss; 0.06678
# EPOCH; 152; Valid.Acc.; 0.956; Loss; 0.06530
# EPOCH; 153; Valid.Acc.; 0.968; Loss; 0.06391
# EPOCH; 154; Valid.Acc.; 0.960; Loss; 0.07309
# EPOCH; 155; Valid.Acc.; 0.964; Loss; 0.09639
# EPOCH; 156; Valid.Acc.; 0.962; Loss; 0.06461
# EPOCH; 157; Valid.Acc.; 0.954; Loss; 0.06705
# EPOCH; 158; Valid.Acc.; 0.959; Loss; 0.08491
# EPOCH; 159; Valid.Acc.; 0.969; Loss; 0.07476
# EPOCH; 160; Valid.Acc.; 0.957; Loss; 0.07295
# EPOCH; 161; Valid.Acc.; 0.963; Loss; 0.06667
# EPOCH; 162; Valid.Acc.; 0.967; Loss; 0.07212
# EPOCH; 163; Valid.Acc.; 0.963; Loss; 0.07104
# EPOCH; 164; Valid.Acc.; 0.963; Loss; 0.07517
# EPOCH; 165; Valid.Acc.; 0.958; Loss; 0.08328
# EPOCH; 166; Valid.Acc.; 0.969; Loss; 0.06622
# EPOCH; 167; Valid.Acc.; 0.942; Loss; 0.06588
# EPOCH; 168; Valid.Acc.; 0.968; Loss; 0.07659
# EPOCH; 169; Valid.Acc.; 0.961; Loss; 0.06671
# EPOCH; 170; Valid.Acc.; 0.970; Loss; 0.12459
# EPOCH; 171; Valid.Acc.; 0.958; Loss; 0.21267
# EPOCH; 172; Valid.Acc.; 0.957; Loss; 0.06472
# EPOCH; 173; Valid.Acc.; 0.953; Loss; 0.06377
# EPOCH; 174; Valid.Acc.; 0.963; Loss; 0.06596
# EPOCH; 175; Valid.Acc.; 0.963; Loss; 0.07001
# EPOCH; 176; Valid.Acc.; 0.972; Loss; 0.06441
# EPOCH; 177; Valid.Acc.; 0.965; Loss; 0.38057
# EPOCH; 178; Valid.Acc.; 0.961; Loss; 0.06804
# EPOCH; 179; Valid.Acc.; 0.965; Loss; 0.06556
# EPOCH; 180; Valid.Acc.; 0.959; Loss; 0.06584
# EPOCH; 181; Valid.Acc.; 0.961; Loss; 0.06704
# EPOCH; 182; Valid.Acc.; 0.966; Loss; 0.06539
# EPOCH; 183; Valid.Acc.; 0.967; Loss; 0.06450
# EPOCH; 184; Valid.Acc.; 0.957; Loss; 0.06627
# EPOCH; 185; Valid.Acc.; 0.963; Loss; 0.06352
# EPOCH; 186; Valid.Acc.; 0.959; Loss; 0.06430
# EPOCH; 187; Valid.Acc.; 0.965; Loss; 0.06376
# EPOCH; 188; Valid.Acc.; 0.966; Loss; 0.06462
# EPOCH; 189; Valid.Acc.; 0.957; Loss; 0.06486
# EPOCH; 190; Valid.Acc.; 0.966; Loss; 0.06392
# EPOCH; 191; Valid.Acc.; 0.957; Loss; 0.06483
# EPOCH; 192; Valid.Acc.; 0.971; Loss; 0.07560
# EPOCH; 193; Valid.Acc.; 0.963; Loss; 0.07427
# EPOCH; 194; Valid.Acc.; 0.966; Loss; 0.33330
# EPOCH; 195; Valid.Acc.; 0.963; Loss; 0.11739
# EPOCH; 196; Valid.Acc.; 0.973; Loss; 0.06623
# EPOCH; 197; Valid.Acc.; 0.964; Loss; 0.06443
# EPOCH; 198; Valid.Acc.; 0.962; Loss; 0.06463
# EPOCH; 199; Valid.Acc.; 0.951; Loss; 0.07343
# EPOCH; 200; Valid.Acc.; 0.968; Loss; 0.06543
# Model saved
# Test Accuracy = 0.946

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('.'))

    test_accuracy = evaluate(X_train_processed, y_train)
    print("Train Accuracy = {:.3f}".format(test_accuracy))
# Out:
# Train Accuracy = 0.995

# %% [markdown]
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.

# %% [markdown]
# ### Load and Output the Images

# %%
import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg

img_folder = './examples/'
test_images = []
test_responses = [1, 22, 18, 38, 17, 23]
fig = plt.figure(figsize=(16,4))
fig.suptitle('Test images from the web', fontsize=16)


cnt = 0
for img_name in os.listdir(img_folder):
    image = mpimg.imread(img_folder+img_name)
    image_to_show = cv2.resize(image, (200, 200), interpolation = cv2.INTER_AREA)
    image = cv2.resize(image, (32, 32), interpolation = cv2.INTER_AREA)
    cnt = cnt+1
    sub=plt.subplot(1,6,cnt)
    sub.set_title(img_name)
    plt.imshow(image_to_show)
    image = preprocess_image(image) 
    test_images.append(image)
    
    
test_images = np.array(test_images)

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
   
pred_val = tf.argmax(logits, 1)
pred_softmax = tf.nn.softmax(logits)
pred_topFive = tf.nn.top_k(pred_softmax, k=5)
    
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('.'))
    pred_val_out, pred_topFive_out = sess.run( [pred_val, pred_topFive], feed_dict={x:  test_images, y: test_responses})
    
print("Predicted Labels")
print(pred_val_out)
print()


with open('signnames.csv') as csvfile:
    next(csvfile) # ignore header
    a = [ row.strip().split(',') for row in csvfile]
    signnames_dict = dict((data[0],data[1:]) for data in a)
    
cnt = 0
correct_cnt = 0
for i in pred_val_out:
    correctness = "Correct"
    if test_responses[cnt] == i:
        correctness = "Correct"
        correct_cnt = correct_cnt + 1
    else:
        correctness = "Not correct!"
      
    print("{} - {} -> {}".format(i, signnames_dict[str(i)], correctness))
    cnt = cnt + 1
# Out:
# Predicted Labels
# [ 1 22 18 38 17 23]
#
# 1 - ['Speed limit (30km/h)'] -> Correct
# 22 - ['Bumpy road'] -> Correct
# 18 - ['General caution'] -> Correct
# 38 - ['Keep right'] -> Correct
# 17 - ['No entry'] -> Correct
# 23 - ['Slippery road'] -> Correct

# %% [markdown]
# ### Analyze Performance

# %%
print("Accuracy for the tested images equals: {:.2f} %".format(correct_cnt/cnt*100))
# Out:
# Accuracy for the tested images equals: 100.00 %

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %%
print('Top 5 softmax probabilities for fach test image')
print(pred_topFive_out)

top_k_values = pred_topFive_out[0]
top_k_indices = pred_topFive_out[1]

ind = np.arange(5) 

for i in range(6):
    plt.figure(figsize=(4,2))
    values = top_k_values[i]
    plt.bar(ind, values, 0.2, color='b')
    plt.ylabel('Softmax probability')
    plt.xlabel('Labels')
    plt.title('Top 5 Softmax Probabilities for Test Image {}'.format(str(i+1)))
    plt.xticks(ind, tuple(top_k_indices[i]))

plt.show()
# Out:
# Top 5 softmax probabilities for fach test image
# TopKV2(values=array([[  9.47164595e-01,   3.20238657e-02,   9.72876139e-03,
#           6.71847770e-03,   2.44425377e-03],
#        [  9.99999404e-01,   6.45489763e-07,   2.35706832e-09,
#           6.43225219e-13,   5.91092320e-14],
#        [  1.00000000e+00,   2.07804542e-12,   1.57971340e-14,
#           3.70260378e-15,   3.36661948e-15],
#        [  1.00000000e+00,   1.03427735e-11,   5.88227221e-13,
#           2.42548901e-13,   1.47672510e-13],
#        [  9.99850512e-01,   7.39571478e-05,   4.28794374e-05,
#           2.90558783e-05,   2.47452112e-06],
#        [  1.00000000e+00,   1.78221272e-12,   1.47596269e-12,
#           1.12347870e-12,   8.59638261e-13]], dtype=float32), indices=array([[ 1,  4,  5,  2, 14],
#        [22, 31, 28, 20, 18],
#        [18, 26, 25, 11, 27],
#        [38, 36, 34, 20, 25],
#        [17, 41, 35, 12, 42],
#        [23, 37, 30, 28, 19]]))
